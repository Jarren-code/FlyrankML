# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jarren-code/FlyrankML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My lane is momentum prediction.
# I chose this lane because I'm interested in the why behind trends like stock price movements.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# My work would aid as a reference for financial analyses and stock purchases.
# Stock investors may use it as a tool to supplement their fundamental and technical analyses of stocks before investing.
# A wrong recommendation may confuse the investor when they should've trusted their own judgment, an example of this is
# if the investor thinks it's better to sell immediately but the model tells them to wait, they may end up losing money if they follow the model recommendation.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# 22 parquet files across dataset
# 78,835,655 rows in fact_content_daily_performance


# Below is the code I used to obtain these numbers:

# import sys
# !{sys.executable} -m pip install duckdb
# import duckdb
# con = duckdb.connect()

# NOTE: We request a read token from huggingface to replace 'hf_your_read_token'
# con.execute("CREATE SECRET (TYPE huggingface, TOKEN 'hf_your_read_token')") #accept the gate in-browser first, then paste a READ token

# rel = "hf://datasets/FlyRank/internship-warehouse"
# con.sql(f"SELECT COUNT(*) FROM read_parquet('{rel}/fact_content_daily_performance/**/*.parquet')")
# con.sql(f"SELECT * FROM glob('{rel}/**/*.parquet') LIMIT 50")
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# /tmp/ipykernel_1865/2714105007.py in <cell line: 0>()
#       5 con.execute("CREATE SECRET (TYPE huggingface, TOKEN 'hf_your_read_token')") #accept the gate in-browser first, then paste a READ token
#       6 rel = "hf://datasets/FlyRank/internship-warehouse"
# ----> 7 con.sql(f"SELECT COUNT(*) FROM read_parquet('{rel}/fact_content_daily_performance/**/*.parquet')")
#       8 con.sql(f"SELECT * FROM glob('{rel}/**/*.parquet') LIMIT 50")
#
# HTTPException: HTTP Error: HTTP GET error on 'https://huggingface.co/datasets/FlyRank/internship-warehouse/resolve/main/fact_content_daily_performance/month=2025-01/data_0.parquet' (HTTP 401)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What my work will be able to say:
#1. Trends (e.g. stock price trends)
#2. Decision-support (recommendations for the user)

# %%
# What my work will never be able to say:
# 1. Causal proof (some variables may be caused by more than just one factor)

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
